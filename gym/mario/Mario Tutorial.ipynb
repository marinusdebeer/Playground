# %% [markdown]
# # 1. Setup Mario

# %%
# !pip install gym_super_mario_bros==7.3.0 nes_py

# %%
# Import the game
import gym_super_mario_bros
# Import the Joypad wrapper
from nes_py.wrappers import JoypadSpace
# Import the SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
# Setup game
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %%
# Create a flag - restart or not
# done = True
# # Loop through each frame in the game
# for step in range(100000): 
#     # Start the game to begin with 
#     if done: 
#         # Start the gamee
#         env.reset()
#     # Do random actions
#     state, reward, done, info = env.step(env.action_space.sample())
#     # Show the game on the screen
#     env.render()
# # Close the game
# env.close()

# %% [markdown]
# # 2. Preprocess Environment

# %%
# Install pytorch
# !pip install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio===0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html

# %%
# Install stable baselines for RL stuff
# !pip install stable-baselines3[extra]

# %%
# Import Frame Stacker Wrapper and GrayScaling Wrapper
from gym.wrappers import GrayScaleObservation
# Import Vectorization Wrappers
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
# Import Matplotlib to show the impact of frame stacking
from matplotlib import pyplot as plt

# %%
# 1. Create the base environment
env = gym_super_mario_bros.make('SuperMarioBros-v0')
# 2. Simplify the controls 
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# 3. Grayscale
env = GrayScaleObservation(env, keep_dim=True)
# 4. Wrap inside the Dummy Environment
env = DummyVecEnv([lambda: env])
# 5. Stack the frames
env = VecFrameStack(env, 4, channels_order='last')

# %%
state = env.reset()

# %%
state, reward, done, info = env.step([5])

# %%
plt.figure(figsize=(20,16))
for idx in range(state.shape[3]):
    plt.subplot(1,4,idx+1)
    plt.imshow(state[0][:,:,idx])
plt.show()

# %% [markdown]
# # 3. Train the RL Model

# %%
# Import os for file path management
import os 
# Import PPO for algos
from stable_baselines3 import PPO
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
# This is the AI model started
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.001, n_steps=512) #learning_rate=0.000001
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
# Train the AI model, this is where the AI model starts to learn
model.learn(total_timesteps=1_000_000, callback=callback)
# Out:
# Logging to ./logs/PPO_3
# ----------------------------
# | time/              |     |
# |    fps             | 153 |
# |    iterations      | 1   |
# |    time_elapsed    | 3   |
# |    total_timesteps | 512 |
# ----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 18         |
# |    iterations           | 2          |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 1024       |
# | train/                  |            |
# |    approx_kl            | 0.14149183 |
# |    clip_fraction        | 0.596      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.83      |
# |    explained_variance   | 0.00708    |
# |    learning_rate        | 0.001      |
# |    loss                 | 6.13       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | 0.083      |
# |    value_loss           | 83.1       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 3         |
# |    time_elapsed         | 106       |
# |    total_timesteps      | 1536      |
# | train/                  |           |
# |    approx_kl            | 1.0739865 |
# |    clip_fraction        | 0.619     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | -0.255    |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.963     |
# |    n_updates            | 20        |
# |    policy_gradient_loss | 0.087     |
# |    value_loss           | 23.5      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 13        |
# |    iterations           | 4         |
# |    time_elapsed         | 157       |
# |    total_timesteps      | 2048      |
# | train/                  |           |
# |    approx_kl            | 0.7783355 |
# |    clip_fraction        | 0.618     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.53     |
# |    explained_variance   | 0.104     |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.373     |
# |    n_updates            | 30        |
# |    policy_gradient_loss | 0.0281    |
# |    value_loss           | 4.6       |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 5           |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.014100678 |
# |    clip_fraction        | 0.00937     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0864     |
# |    explained_variance   | 0.149       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.47        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.00207     |
# |    value_loss           | 4.82        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 11            |
# |    iterations           | 6             |
# |    time_elapsed         | 256           |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 0.00039356842 |
# |    clip_fraction        | 0.00293       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0945       |
# |    explained_variance   | 0.275         |
# |    learning_rate        | 0.001         |
# |    loss                 | 1.07          |
# |    n_updates            | 50            |
# |    policy_gradient_loss | 0.00315       |
# |    value_loss           | 4.64          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 11            |
# |    iterations           | 7             |
# |    time_elapsed         | 307           |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 0.00024876278 |
# |    clip_fraction        | 0.00391       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0766       |
# |    explained_variance   | 0.42          |
# |    learning_rate        | 0.001         |
# |    loss                 | 0.222         |
# |    n_updates            | 60            |
# |    policy_gradient_loss | 0.000875      |
# |    value_loss           | 2.25          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 8            |
# |    time_elapsed         | 357          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0028802752 |
# |    clip_fraction        | 0.00859      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.11        |
# |    explained_variance   | 0.504        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.103        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | 0.000256     |
# |    value_loss           | 0.716        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 9           |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.044974163 |
# |    clip_fraction        | 0.0418      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.344      |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.169       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.000576   |
# |    value_loss           | 3.8         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 10         |
# |    time_elapsed         | 458        |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.05392982 |
# |    clip_fraction        | 0.0814     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.403     |
# |    explained_variance   | 0.454      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0729     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | 0.00481    |
# |    value_loss           | 0.378      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 11          |
# |    time_elapsed         | 509         |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.010062493 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.521      |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0423      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00329     |
# |    value_loss           | 0.265       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 12          |
# |    time_elapsed         | 560         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013247435 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.514      |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0558      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.015       |
# |    value_loss           | 0.253       |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 13        |
# |    time_elapsed         | 612       |
# |    total_timesteps      | 6656      |
# | train/                  |           |
# |    approx_kl            | 0.0117552 |
# |    clip_fraction        | 0.152     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.419    |
# |    explained_variance   | 0.266     |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.058     |
# |    n_updates            | 120       |
# |    policy_gradient_loss | 0.0169    |
# |    value_loss           | 0.171     |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 14          |
# |    time_elapsed         | 664         |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.031025013 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.47       |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0445      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00626    |
# |    value_loss           | 0.163       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 15          |
# |    time_elapsed         | 716         |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.050406672 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.51       |
# |    explained_variance   | 0.264       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0158      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 0.132       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 16          |
# |    time_elapsed         | 767         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.039780643 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | 0.0845      |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.00276     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00958    |
# |    value_loss           | 0.125       |
# -----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 10       |
# |    iterations           | 17       |
# |    time_elapsed         | 817      |
# |    total_timesteps      | 8704     |
# | train/                  |          |
# |    approx_kl            | 7.578433 |
# |    clip_fraction        | 0.563    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.162   |
# |    explained_variance   | 0.00468  |
# |    learning_rate        | 0.001    |
# |    loss                 | 7.45     |
# |    n_updates            | 160      |
# |    policy_gradient_loss | 0.148    |
# |    value_loss           | 113      |
# --------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 18         |
# |    time_elapsed         | 867        |
# |    total_timesteps      | 9216       |
# | train/                  |            |
# |    approx_kl            | 0.06639282 |
# |    clip_fraction        | 0.00156    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.000644  |
# |    explained_variance   | 0.443      |
# |    learning_rate        | 0.001      |
# |    loss                 | 24         |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.00172    |
# |    value_loss           | 80.9       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 19        |
# |    time_elapsed         | 917       |
# |    total_timesteps      | 9728      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.97e-13 |
# |    explained_variance   | 0.723     |
# |    learning_rate        | 0.001     |
# |    loss                 | 47.2      |
# |    n_updates            | 180       |
# |    policy_gradient_loss | 5.68e-09  |
# |    value_loss           | 108       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 20        |
# |    time_elapsed         | 968       |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.48e-14 |
# |    explained_variance   | 0.781     |
# |    learning_rate        | 0.001     |
# |    loss                 | 30.1      |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -2.33e-09 |
# |    value_loss           | 154       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 21        |
# |    time_elapsed         | 1019      |
# |    total_timesteps      | 10752     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.12e-18 |
# |    explained_variance   | 0.763     |
# |    learning_rate        | 0.001     |
# |    loss                 | 57.1      |
# |    n_updates            | 200       |
# |    policy_gradient_loss | 6.72e-09  |
# |    value_loss           | 130       |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 10       |
# |    iterations           | 22       |
# |    time_elapsed         | 1070     |
# |    total_timesteps      | 11264    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -7.4e-19 |
# |    explained_variance   | 0.781    |
# |    learning_rate        | 0.001    |
# |    loss                 | 72.3     |
# |    n_updates            | 210      |
# |    policy_gradient_loss | 3.73e-09 |
# |    value_loss           | 138      |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 23        |
# |    time_elapsed         | 1120      |
# |    total_timesteps      | 11776     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.78e-17 |
# |    explained_variance   | 0.742     |
# |    learning_rate        | 0.001     |
# |    loss                 | 98.5      |
# |    n_updates            | 220       |
# |    policy_gradient_loss | 1.16e-11  |
# |    value_loss           | 221       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 24        |
# |    time_elapsed         | 1170      |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.88e-20 |
# |    explained_variance   | 0.748     |
# |    learning_rate        | 0.001     |
# |    loss                 | 95.6      |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -1.34e-09 |
# |    value_loss           | 195       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 25        |
# |    time_elapsed         | 1221      |
# |    total_timesteps      | 12800     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.44e-19 |
# |    explained_variance   | 0.725     |
# |    learning_rate        | 0.001     |
# |    loss                 | 139       |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -4.8e-09  |
# |    value_loss           | 198       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 26        |
# |    time_elapsed         | 1272      |
# |    total_timesteps      | 13312     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -9.92e-21 |
# |    explained_variance   | 0.693     |
# |    learning_rate        | 0.001     |
# |    loss                 | 209       |
# |    n_updates            | 250       |
# |    policy_gradient_loss | -1.16e-09 |
# |    value_loss           | 208       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 27        |
# |    time_elapsed         | 1323      |
# |    total_timesteps      | 13824     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.68e-17 |
# |    explained_variance   | 0.699     |
# |    learning_rate        | 0.001     |
# |    loss                 | 220       |
# |    n_updates            | 260       |
# |    policy_gradient_loss | -1.02e-10 |
# |    value_loss           | 253       |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 10       |
# |    iterations           | 28       |
# |    time_elapsed         | 1377     |
# |    total_timesteps      | 14336    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -5.5e-14 |
# |    explained_variance   | 0.7      |
# |    learning_rate        | 0.001    |
# |    loss                 | 88.8     |
# |    n_updates            | 270      |
# |    policy_gradient_loss | 1.27e-09 |
# |    value_loss           | 195      |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 29        |
# |    time_elapsed         | 1429      |
# |    total_timesteps      | 14848     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.08e-14 |
# |    explained_variance   | 0.738     |
# |    learning_rate        | 0.001     |
# |    loss                 | 165       |
# |    n_updates            | 280       |
# |    policy_gradient_loss | 3.2e-10   |
# |    value_loss           | 198       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 30        |
# |    time_elapsed         | 1480      |
# |    total_timesteps      | 15360     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.58e-13 |
# |    explained_variance   | 0.713     |
# |    learning_rate        | 0.001     |
# |    loss                 | 119       |
# |    n_updates            | 290       |
# |    policy_gradient_loss | 5.85e-10  |
# |    value_loss           | 192       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 31        |
# |    time_elapsed         | 1534      |
# |    total_timesteps      | 15872     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.51e-13 |
# |    explained_variance   | 0.689     |
# |    learning_rate        | 0.001     |
# |    loss                 | 90        |
# |    n_updates            | 300       |
# |    policy_gradient_loss | -2.79e-10 |
# |    value_loss           | 224       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 32        |
# |    time_elapsed         | 1586      |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.91e-12 |
# |    explained_variance   | 0.729     |
# |    learning_rate        | 0.001     |
# |    loss                 | 92        |
# |    n_updates            | 310       |
# |    policy_gradient_loss | -3.8e-10  |
# |    value_loss           | 214       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 33        |
# |    time_elapsed         | 1639      |
# |    total_timesteps      | 16896     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.92e-14 |
# |    explained_variance   | 0.683     |
# |    learning_rate        | 0.001     |
# |    loss                 | 298       |
# |    n_updates            | 320       |
# |    policy_gradient_loss | 3.74e-09  |
# |    value_loss           | 258       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 34        |
# |    time_elapsed         | 1692      |
# |    total_timesteps      | 17408     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.31e-11 |
# |    explained_variance   | 0.698     |
# |    learning_rate        | 0.001     |
# |    loss                 | 106       |
# |    n_updates            | 330       |
# |    policy_gradient_loss | 3.36e-10  |
# |    value_loss           | 240       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 35        |
# |    time_elapsed         | 1744      |
# |    total_timesteps      | 17920     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.67e-07 |
# |    explained_variance   | 0.71      |
# |    learning_rate        | 0.001     |
# |    loss                 | 142       |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -1.04e-07 |
# |    value_loss           | 234       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 36        |
# |    time_elapsed         | 1798      |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.89e-09 |
# |    explained_variance   | 0.717     |
# |    learning_rate        | 0.001     |
# |    loss                 | 51.5      |
# |    n_updates            | 350       |
# |    policy_gradient_loss | 9.83e-09  |
# |    value_loss           | 248       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 37        |
# |    time_elapsed         | 1851      |
# |    total_timesteps      | 18944     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.86e-09 |
# |    explained_variance   | 0.715     |
# |    learning_rate        | 0.001     |
# |    loss                 | 125       |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -1.57e-10 |
# |    value_loss           | 250       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 38        |
# |    time_elapsed         | 1912      |
# |    total_timesteps      | 19456     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.65e-05 |
# |    explained_variance   | 0.691     |
# |    learning_rate        | 0.001     |
# |    loss                 | 144       |
# |    n_updates            | 370       |
# |    policy_gradient_loss | -9.09e-06 |
# |    value_loss           | 353       |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 10       |
# |    iterations           | 39       |
# |    time_elapsed         | 1965     |
# |    total_timesteps      | 19968    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -4.4e-08 |
# |    explained_variance   | 0.733    |
# |    learning_rate        | 0.001    |
# |    loss                 | 96.2     |
# |    n_updates            | 380      |
# |    policy_gradient_loss | 7.86e-10 |
# |    value_loss           | 241      |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 40        |
# |    time_elapsed         | 2017      |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.28e-09 |
# |    explained_variance   | 0.734     |
# |    learning_rate        | 0.001     |
# |    loss                 | 201       |
# |    n_updates            | 390       |
# |    policy_gradient_loss | 1.05e-10  |
# |    value_loss           | 260       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 41        |
# |    time_elapsed         | 2072      |
# |    total_timesteps      | 20992     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.21e-10 |
# |    explained_variance   | 0.71      |
# |    learning_rate        | 0.001     |
# |    loss                 | 154       |
# |    n_updates            | 400       |
# |    policy_gradient_loss | 8.6e-10   |
# |    value_loss           | 294       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 42        |
# |    time_elapsed         | 2125      |
# |    total_timesteps      | 21504     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -8.41e-09 |
# |    explained_variance   | 0.702     |
# |    learning_rate        | 0.001     |
# |    loss                 | 142       |
# |    n_updates            | 410       |
# |    policy_gradient_loss | -9.02e-11 |
# |    value_loss           | 260       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 43        |
# |    time_elapsed         | 2178      |
# |    total_timesteps      | 22016     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.41e-06 |
# |    explained_variance   | 0.678     |
# |    learning_rate        | 0.001     |
# |    loss                 | 34.5      |
# |    n_updates            | 420       |
# |    policy_gradient_loss | -1.37e-06 |
# |    value_loss           | 272       |
# ---------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 44            |
# |    time_elapsed         | 2231          |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 6.9034286e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.59e-05     |
# |    explained_variance   | 0.704         |
# |    learning_rate        | 0.001         |
# |    loss                 | 92.1          |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -4.73e-06     |
# |    value_loss           | 260           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 45           |
# |    time_elapsed         | 2284         |
# |    total_timesteps      | 23040        |
# | train/                  |              |
# |    approx_kl            | 8.898787e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.23e-05    |
# |    explained_variance   | 0.715        |
# |    learning_rate        | 0.001        |
# |    loss                 | 106          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 6.47e-05     |
# |    value_loss           | 216          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 46            |
# |    time_elapsed         | 2337          |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 4.6216883e-08 |
# |    clip_fraction        | 0.000391      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000534     |
# |    explained_variance   | 0.727         |
# |    learning_rate        | 0.001         |
# |    loss                 | 18.6          |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000228     |
# |    value_loss           | 210           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 47           |
# |    time_elapsed         | 2389         |
# |    total_timesteps      | 24064        |
# | train/                  |              |
# |    approx_kl            | 0.0036172662 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.000225    |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.001        |
# |    loss                 | 137          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -7.91e-05    |
# |    value_loss           | 208          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 48          |
# |    time_elapsed         | 2442        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007299505 |
# |    clip_fraction        | 0.00195     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0004     |
# |    explained_variance   | 0.669       |
# |    learning_rate        | 0.001       |
# |    loss                 | 169         |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00037    |
# |    value_loss           | 275         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 49           |
# |    time_elapsed         | 2495         |
# |    total_timesteps      | 25088        |
# | train/                  |              |
# |    approx_kl            | 0.0071087433 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.000129    |
# |    explained_variance   | 0.733        |
# |    learning_rate        | 0.001        |
# |    loss                 | 64.1         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000837    |
# |    value_loss           | 218          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 50            |
# |    time_elapsed         | 2547          |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 1.0409858e-06 |
# |    clip_fraction        | 0.000781      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000754     |
# |    explained_variance   | 0.74          |
# |    learning_rate        | 0.001         |
# |    loss                 | 179           |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000222     |
# |    value_loss           | 199           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 51            |
# |    time_elapsed         | 2601          |
# |    total_timesteps      | 26112         |
# | train/                  |               |
# |    approx_kl            | 3.4945784e-05 |
# |    clip_fraction        | 0.000977      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00134      |
# |    explained_variance   | 0.756         |
# |    learning_rate        | 0.001         |
# |    loss                 | 132           |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000168     |
# |    value_loss           | 186           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 52            |
# |    time_elapsed         | 2653          |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00057430984 |
# |    clip_fraction        | 0.00176       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00133      |
# |    explained_variance   | 0.756         |
# |    learning_rate        | 0.001         |
# |    loss                 | 111           |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000206     |
# |    value_loss           | 196           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 53           |
# |    time_elapsed         | 2706         |
# |    total_timesteps      | 27136        |
# | train/                  |              |
# |    approx_kl            | 0.0048204884 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.000477    |
# |    explained_variance   | 0.776        |
# |    learning_rate        | 0.001        |
# |    loss                 | 186          |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000204    |
# |    value_loss           | 187          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 54          |
# |    time_elapsed         | 2759        |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.001576394 |
# |    clip_fraction        | 0.000977    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00193    |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.001       |
# |    loss                 | 158         |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.000188   |
# |    value_loss           | 197         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 55          |
# |    time_elapsed         | 2810        |
# |    total_timesteps      | 28160       |
# | train/                  |             |
# |    approx_kl            | 0.009718616 |
# |    clip_fraction        | 0.00176     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00123    |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.001       |
# |    loss                 | 18.4        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.000282   |
# |    value_loss           | 201         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 56          |
# |    time_elapsed         | 2862        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018856546 |
# |    clip_fraction        | 0.00195     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.000172   |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.001       |
# |    loss                 | 66.9        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.000182   |
# |    value_loss           | 216         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 57            |
# |    time_elapsed         | 2916          |
# |    total_timesteps      | 29184         |
# | train/                  |               |
# |    approx_kl            | 1.1641532e-10 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.51e-06     |
# |    explained_variance   | 0.702         |
# |    learning_rate        | 0.001         |
# |    loss                 | 54.5          |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -3.72e-07     |
# |    value_loss           | 212           |
# -------------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 9        |
# |    iterations           | 58       |
# |    time_elapsed         | 2971     |
# |    total_timesteps      | 29696    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -3e-06   |
# |    explained_variance   | 0.716    |
# |    learning_rate        | 0.001    |
# |    loss                 | 28.1     |
# |    n_updates            | 570      |
# |    policy_gradient_loss | 5.28e-09 |
# |    value_loss           | 231      |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 9         |
# |    iterations           | 59        |
# |    time_elapsed         | 3024      |
# |    total_timesteps      | 30208     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.46e-07 |
# |    explained_variance   | 0.706     |
# |    learning_rate        | 0.001     |
# |    loss                 | 110       |
# |    n_updates            | 580       |
# |    policy_gradient_loss | 3.38e-10  |
# |    value_loss           | 235       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 9         |
# |    iterations           | 60        |
# |    time_elapsed         | 3078      |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.81e-07 |
# |    explained_variance   | 0.731     |
# |    learning_rate        | 0.001     |
# |    loss                 | 174       |
# |    n_updates            | 590       |
# |    policy_gradient_loss | 3.42e-08  |
# |    value_loss           | 247       |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 61           |
# |    time_elapsed         | 3132         |
# |    total_timesteps      | 31232        |
# | train/                  |              |
# |    approx_kl            | 9.313226e-10 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.43e-06    |
# |    explained_variance   | 0.74         |
# |    learning_rate        | 0.001        |
# |    loss                 | 181          |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -7.47e-08    |
# |    value_loss           | 245          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 62           |
# |    time_elapsed         | 3185         |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 4.656613e-10 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.18e-06    |
# |    explained_variance   | 0.745        |
# |    learning_rate        | 0.001        |
# |    loss                 | 50.4         |
# |    n_updates            | 610          |
# |    policy_gradient_loss | 6.88e-07     |
# |    value_loss           | 226          |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 9         |
# |    iterations           | 63        |
# |    time_elapsed         | 3238      |
# |    total_timesteps      | 32256     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.53e-06 |
# |    explained_variance   | 0.754     |
# |    learning_rate        | 0.001     |
# |    loss                 | 126       |
# |    n_updates            | 620       |
# |    policy_gradient_loss | -4.17e-08 |
# |    value_loss           | 236       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 9         |
# |    iterations           | 64        |
# |    time_elapsed         | 3292      |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.45e-09 |
# |    explained_variance   | 0.668     |
# |    learning_rate        | 0.001     |
# |    loss                 | 133       |
# |    n_updates            | 630       |
# |    policy_gradient_loss | 1.34e-09  |
# |    value_loss           | 301       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 9         |
# |    iterations           | 65        |
# |    time_elapsed         | 3348      |
# |    total_timesteps      | 33280     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.12e-06 |
# |    explained_variance   | 0.713     |
# |    learning_rate        | 0.001     |
# |    loss                 | 145       |
# |    n_updates            | 640       |
# |    policy_gradient_loss | -4.41e-08 |
# |    value_loss           | 245       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 9         |
# |    iterations           | 66        |
# |    time_elapsed         | 3409      |
# |    total_timesteps      | 33792     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# ...
# |    n_updates            | 3660          |
# |    policy_gradient_loss | -4.54e-05     |
# |    value_loss           | 580           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 368           |
# |    time_elapsed         | 26350         |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 2.4097972e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.79e-05     |
# |    explained_variance   | 0.646         |
# |    learning_rate        | 0.001         |
# |    loss                 | 279           |
# |    n_updates            | 3670          |
# |    policy_gradient_loss | -1.65e-05     |
# |    value_loss           | 527           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 369          |
# |    time_elapsed         | 26401        |
# |    total_timesteps      | 188928       |
# | train/                  |              |
# |    approx_kl            | 9.080395e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.000297    |
# |    explained_variance   | 0.737        |
# |    learning_rate        | 0.001        |
# |    loss                 | 164          |
# |    n_updates            | 3680         |
# |    policy_gradient_loss | -9.44e-06    |
# |    value_loss           | 586          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 370         |
# |    time_elapsed         | 26451       |
# |    total_timesteps      | 189440      |
# | train/                  |             |
# |    approx_kl            | 1.44355e-08 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.000124   |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.001       |
# |    loss                 | 233         |
# |    n_updates            | 3690        |
# |    policy_gradient_loss | -8.94e-07   |
# |    value_loss           | 751         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 371           |
# |    time_elapsed         | 26502         |
# |    total_timesteps      | 189952        |
# | train/                  |               |
# |    approx_kl            | 6.9849193e-10 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.32e-06     |
# |    explained_variance   | 0.62          |
# |    learning_rate        | 0.001         |
# |    loss                 | 456           |
# |    n_updates            | 3700          |
# |    policy_gradient_loss | 9.74e-07      |
# |    value_loss           | 579           |
# -------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 7         |
# |    iterations           | 372       |
# |    time_elapsed         | 26555     |
# |    total_timesteps      | 190464    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.91e-05 |
# |    explained_variance   | 0.7       |
# |    learning_rate        | 0.001     |
# |    loss                 | 150       |
# |    n_updates            | 3710      |
# |    policy_gradient_loss | -1.6e-06  |
# |    value_loss           | 567       |
# ---------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 373           |
# |    time_elapsed         | 26607         |
# |    total_timesteps      | 190976        |
# | train/                  |               |
# |    approx_kl            | 1.0477379e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -9.17e-05     |
# |    explained_variance   | 0.64          |
# |    learning_rate        | 0.001         |
# |    loss                 | 239           |
# |    n_updates            | 3720          |
# |    policy_gradient_loss | 7.87e-06      |
# |    value_loss           | 522           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 374           |
# |    time_elapsed         | 26658         |
# |    total_timesteps      | 191488        |
# | train/                  |               |
# |    approx_kl            | 1.1641532e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.84e-05     |
# |    explained_variance   | 0.723         |
# |    learning_rate        | 0.001         |
# |    loss                 | 297           |
# |    n_updates            | 3730          |
# |    policy_gradient_loss | 5.72e-07      |
# |    value_loss           | 538           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 375           |
# |    time_elapsed         | 26709         |
# |    total_timesteps      | 192000        |
# | train/                  |               |
# |    approx_kl            | 2.9356452e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000345     |
# |    explained_variance   | 0.716         |
# |    learning_rate        | 0.001         |
# |    loss                 | 378           |
# |    n_updates            | 3740          |
# |    policy_gradient_loss | 2.24e-05      |
# |    value_loss           | 743           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 376           |
# |    time_elapsed         | 26760         |
# |    total_timesteps      | 192512        |
# | train/                  |               |
# |    approx_kl            | 3.4375116e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000476     |
# |    explained_variance   | 0.638         |
# |    learning_rate        | 0.001         |
# |    loss                 | 375           |
# |    n_updates            | 3750          |
# |    policy_gradient_loss | 6.17e-05      |
# |    value_loss           | 555           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 377           |
# |    time_elapsed         | 26814         |
# |    total_timesteps      | 193024        |
# | train/                  |               |
# |    approx_kl            | 4.5634806e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00016      |
# |    explained_variance   | 0.719         |
# |    learning_rate        | 0.001         |
# |    loss                 | 341           |
# |    n_updates            | 3760          |
# |    policy_gradient_loss | 2.88e-07      |
# |    value_loss           | 567           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 378           |
# |    time_elapsed         | 26872         |
# |    total_timesteps      | 193536        |
# | train/                  |               |
# |    approx_kl            | 2.0617153e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000819     |
# |    explained_variance   | 0.633         |
# |    learning_rate        | 0.001         |
# |    loss                 | 150           |
# |    n_updates            | 3770          |
# |    policy_gradient_loss | 4.48e-05      |
# |    value_loss           | 573           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 379           |
# |    time_elapsed         | 26929         |
# |    total_timesteps      | 194048        |
# | train/                  |               |
# |    approx_kl            | 3.9336737e-07 |
# |    clip_fraction        | 0.000586      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00319      |
# |    explained_variance   | 0.718         |
# |    learning_rate        | 0.001         |
# |    loss                 | 340           |
# |    n_updates            | 3780          |
# |    policy_gradient_loss | -5.89e-05     |
# |    value_loss           | 553           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 380          |
# |    time_elapsed         | 26987        |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 2.628658e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00104     |
# |    explained_variance   | 0.72         |
# |    learning_rate        | 0.001        |
# |    loss                 | 549          |
# |    n_updates            | 3790         |
# |    policy_gradient_loss | 2.3e-05      |
# |    value_loss           | 798          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 381         |
# |    time_elapsed         | 27043       |
# |    total_timesteps      | 195072      |
# | train/                  |             |
# |    approx_kl            | 3.03844e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.000465   |
# |    explained_variance   | 0.632       |
# |    learning_rate        | 0.001       |
# |    loss                 | 233         |
# |    n_updates            | 3800        |
# |    policy_gradient_loss | 6.8e-05     |
# |    value_loss           | 547         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 382           |
# |    time_elapsed         | 27102         |
# |    total_timesteps      | 195584        |
# | train/                  |               |
# |    approx_kl            | 5.5879354e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000428     |
# |    explained_variance   | 0.697         |
# |    learning_rate        | 0.001         |
# |    loss                 | 329           |
# |    n_updates            | 3810          |
# |    policy_gradient_loss | 3.4e-06       |
# |    value_loss           | 560           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 383          |
# |    time_elapsed         | 27160        |
# |    total_timesteps      | 196096       |
# | train/                  |              |
# |    approx_kl            | 5.576294e-08 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00133     |
# |    explained_variance   | 0.647        |
# |    learning_rate        | 0.001        |
# |    loss                 | 242          |
# |    n_updates            | 3820         |
# |    policy_gradient_loss | 0.000188     |
# |    value_loss           | 560          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 384           |
# |    time_elapsed         | 27214         |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 2.1280721e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00116      |
# |    explained_variance   | 0.721         |
# |    learning_rate        | 0.001         |
# |    loss                 | 355           |
# |    n_updates            | 3830          |
# |    policy_gradient_loss | 2.32e-05      |
# |    value_loss           | 539           |
# -------------------------------------------
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#   File "/var/folders/1_/8tjkkw0s5k7bhzr96pfx40dr0000gn/T/ipykernel_51609/3684825806.py", line 2, in <module>
#     model.learn(total_timesteps=1_000_000, callback=callback)
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py", line 308, in learn
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py", line 271, in learn
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py", line 272, in train
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/torch/_tensor.py", line 487, in backward
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/torch/autograd/__init__.py", line 200, in backward
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/pygments/styles/__init__.py", line 82, in get_style_by_name
# ModuleNotFoundError: No module named 'pygments.styles.default'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2057, in showtraceback
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/IPython/core/ultratb.py", line 799, in format_exception_as_a_whole
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/IPython/core/ultratb.py", line 844, in get_records
#   File "/Users/marinus/miniconda3/envs/gpu_venv/lib/python3.8/site-packages/pygments/styles/__init__.py", line 84, in get_style_by_name
# pygments.util.ClassNotFound: Could not find style module 'default', though it should be builtin.

# %%
model.save('thisisatestmodel')

# %% [markdown]
# # 4. Test it Out

# %%
# Load model
model = PPO.load('./train/best_model_1000000')

# %%
state = env.reset()

# %%
# Start the game 
state = env.reset()
# Loop through the game
while True: 
    
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
